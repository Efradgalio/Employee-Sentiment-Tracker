# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer


nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')

from google.colab import drive
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# # Load Dataset

# %%
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/data/Capgemini_Employee_Reviews_from_AmbitionBox.csv'

# Load the data
df = pd.read_csv(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pd.set_option('display.max_colwidth', None)

# Menampilkan 10 baris pertama dari kolom 'Likes' dan 'Dislikes'
print(df[['Likes', 'Dislikes']].head(10))
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Likes  \
# 0                                                                                                                                                                                                                                                                                                                                        Deserved candidates are promoted promptly.\nUnbiased in providing opportunities to employees, regardless of their gender or any other thing
# 1                                                                                                                                                                                                                                                                                                                                                             You got lot of learning platform and monthly learning plan as well.\nPeople will be encourage for cloud certificating.
# 2  Based on which Business Unit you are you will get your experience.\nCompany's policies are good and is followed by most of the top level management people.\nSome BUs respect employees personal time and some are not. They may directly tell you to work extra hours and days though it may not be your fault in developing something.\nYou canSpeak up what are the troubles you are facing anonymously and is heard and actions are taken. That's the best thing....Read More
# 3                                                                                                                                                                                                                                                                                                                                                                                                                 Some client projects are good as they use the latest tech to work.
# 4                                                                                                               I have worked in IBM (4 years) ,TCS (1 year) , this is my 3rd company (1.3 years completed at the time of review) ,  I would say Capgemini is better than IBM and TCS. Work Life balance is very good in capgemini, additionally growth opportunity is also good here if you are hard a worker. At the end don't forget it also depends on your project and manager.
# 5                                                                                                                                                                                                                                                                                                                             All good and their learning platforms and skill development with full free hands and core knowledge expert in very process of projects and deliveries.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                     Flexible timing, good project, learning growth
# 7                                                                                                                                                                                                                                                                                                   You can stay here without a project, without any work on bench. Nobody will fire you. \nYou can stay here, learn from their courses and prepare for some other exam or other job
# 8                                                                                                                                                                                                                                                                                                              The experience might vary based on the project you are tagged to, I'm in Consulting and my team is really supportive, so my overall experience is good no complaints.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                   Learning new features from my project\nWork life balance is good
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Dislikes
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               With designation promotions good salary increment is also required
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                   You will get fully not tech project.\nThere is no variable pay.\nNo, appraisal. \nif you worked hard no one recognise you.\nIncrement will 3 to 4% max to max.
# 2  Some top level management people bring bad name to the company because of their activities which affect good top level management people too.\nSome BUs do micro management and some are asking to work extra hours. My friend's BU asked him to work on Saturday and Sunday which is against company's policy but to he persons who worked like that didn't Speak Up.  Director of the project knows that too and not supportive to employees' voice.\nSome Managers are very good and directly will tell you not to work on weekends.\nSo it is upto in which BU you are and who is your manager....Read More
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Culture, micro management, unprofessional behavior, lack of sensitivity, pathetic HR and PMO
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Medical insurance amount is quite low compare to TCS . Cab pick up and drop is not from home, it's only from near by defined point.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Hike cycle and performance hikes are bit low and average
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  There is no anniversary culture for new employee, of you join on the month of May, you are going to get the hike after 2 years.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                I begged them for a project, but they kept me on bench for a year. I was a fresher, so I was dying for some work\nThe management is terrible, the manager cut my leaves, saying I had an attitude
# 8                                                                                                                                                                                                                                                                No company or job is perfect, the learning opportunity will get stagnated at some point (might not be the case with development project) especially support projects, also there is no opportunity to have a transition into different roles, and the compensation and promotion is average, other than  this cg is a really great place to work.
# 9                                                                                                                                                                                                                                                                                                                                                                                                           There are no long term project, every 10 months once project getting changed. Again KT and machine setting is taking time. Internal politics are there, even if you work hard you will get 2nd rating.

# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# ## Text Cleaning

# %% [markdown]
# ### Lowercase

# %%
# Membuat salinan DataFrame dengan teks yang diubah menjadi huruf kecil
df_processed = df.copy()
df_processed['Likes_cleaned'] = df['Likes'].apply(lambda x: x.lower() if isinstance(x, str) else x)
df_processed['Dislikes_cleaned'] = df['Dislikes'].apply(lambda x: x.lower() if isinstance(x, str) else x)

pd.set_option('display.max_colwidth', None)

# Menampilkan hasilnya
print(df_processed[['Likes_cleaned', 'Dislikes_cleaned']].head(10))
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Likes_cleaned  \
# 0                                                                                                                                                                                                                                                                                                                                        deserved candidates are promoted promptly.\nunbiased in providing opportunities to employees, regardless of their gender or any other thing
# 1                                                                                                                                                                                                                                                                                                                                                             you got lot of learning platform and monthly learning plan as well.\npeople will be encourage for cloud certificating.
# 2  based on which business unit you are you will get your experience.\ncompany's policies are good and is followed by most of the top level management people.\nsome bus respect employees personal time and some are not. they may directly tell you to work extra hours and days though it may not be your fault in developing something.\nyou canspeak up what are the troubles you are facing anonymously and is heard and actions are taken. that's the best thing....read more
# 3                                                                                                                                                                                                                                                                                                                                                                                                                 some client projects are good as they use the latest tech to work.
# 4                                                                                                               i have worked in ibm (4 years) ,tcs (1 year) , this is my 3rd company (1.3 years completed at the time of review) ,  i would say capgemini is better than ibm and tcs. work life balance is very good in capgemini, additionally growth opportunity is also good here if you are hard a worker. at the end don't forget it also depends on your project and manager.
# 5                                                                                                                                                                                                                                                                                                                             all good and their learning platforms and skill development with full free hands and core knowledge expert in very process of projects and deliveries.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                     flexible timing, good project, learning growth
# 7                                                                                                                                                                                                                                                                                                   you can stay here without a project, without any work on bench. nobody will fire you. \nyou can stay here, learn from their courses and prepare for some other exam or other job
# 8                                                                                                                                                                                                                                                                                                              the experience might vary based on the project you are tagged to, i'm in consulting and my team is really supportive, so my overall experience is good no complaints.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                   learning new features from my project\nwork life balance is good
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Dislikes_cleaned
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               with designation promotions good salary increment is also required
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                   you will get fully not tech project.\nthere is no variable pay.\nno, appraisal. \nif you worked hard no one recognise you.\nincrement will 3 to 4% max to max.
# 2  some top level management people bring bad name to the company because of their activities which affect good top level management people too.\nsome bus do micro management and some are asking to work extra hours. my friend's bu asked him to work on saturday and sunday which is against company's policy but to he persons who worked like that didn't speak up.  director of the project knows that too and not supportive to employees' voice.\nsome managers are very good and directly will tell you not to work on weekends.\nso it is upto in which bu you are and who is your manager....read more
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     culture, micro management, unprofessional behavior, lack of sensitivity, pathetic hr and pmo
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                              medical insurance amount is quite low compare to tcs . cab pick up and drop is not from home, it's only from near by defined point.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         hike cycle and performance hikes are bit low and average
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  there is no anniversary culture for new employee, of you join on the month of may, you are going to get the hike after 2 years.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                i begged them for a project, but they kept me on bench for a year. i was a fresher, so i was dying for some work\nthe management is terrible, the manager cut my leaves, saying i had an attitude
# 8                                                                                                                                                                                                                                                                no company or job is perfect, the learning opportunity will get stagnated at some point (might not be the case with development project) especially support projects, also there is no opportunity to have a transition into different roles, and the compensation and promotion is average, other than  this cg is a really great place to work.
# 9                                                                                                                                                                                                                                                                                                                                                                                                           there are no long term project, every 10 months once project getting changed. again kt and machine setting is taking time. internal politics are there, even if you work hard you will get 2nd rating.

# %% [markdown]
# ### Stop Words

# %%
import nltk
from nltk.corpus import stopwords

# Unduh daftar stopwords bahasa Inggris
nltk.download('stopwords')

# Daftar stopwords bahasa Inggris
stop_words = set(stopwords.words('english'))

# Fungsi untuk menghapus stopwords
def remove_stopwords(text):
    if not isinstance(text, str):
        return text  # Kembalikan teks yang tidak berbentuk string
    words = text.split()  # Pisahkan teks menjadi kata-kata
    filtered_words = [word for word in words if word.lower() not in stop_words]  # Hapus stopwords
    return ' '.join(filtered_words)  # Gabungkan kembali kata-kata menjadi teks

# Pastikan semua nilai dalam kolom 'Likes_cleaned' dan 'Dislikes_cleaned' adalah string
df_processed['Likes_cleaned'] = df_processed['Likes_cleaned'].astype(str).apply(remove_stopwords)
df_processed['Dislikes_cleaned'] = df_processed['Dislikes_cleaned'].astype(str).apply(remove_stopwords)

# Menampilkan hasilnya

print(df_processed[['Likes','Dislikes','Likes_cleaned', 'Dislikes_cleaned']].head(5))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Likes  \
# 0                                                                                                                                                                                                                                                                                                                                        Deserved candidates are promoted promptly.\nUnbiased in providing opportunities to employees, regardless of their gender or any other thing
# 1                                                                                                                                                                                                                                                                                                                                                             You got lot of learning platform and monthly learning plan as well.\nPeople will be encourage for cloud certificating.
# 2  Based on which Business Unit you are you will get your experience.\nCompany's policies are good and is followed by most of the top level management people.\nSome BUs respect employees personal time and some are not. They may directly tell you to work extra hours and days though it may not be your fault in developing something.\nYou canSpeak up what are the troubles you are facing anonymously and is heard and actions are taken. That's the best thing....Read More
# 3                                                                                                                                                                                                                                                                                                                                                                                                                 Some client projects are good as they use the latest tech to work.
# 4                                                                                                               I have worked in IBM (4 years) ,TCS (1 year) , this is my 3rd company (1.3 years completed at the time of review) ,  I would say Capgemini is better than IBM and TCS. Work Life balance is very good in capgemini, additionally growth opportunity is also good here if you are hard a worker. At the end don't forget it also depends on your project and manager.
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Dislikes  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               With designation promotions good salary increment is also required
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                   You will get fully not tech project.\nThere is no variable pay.\nNo, appraisal. \nif you worked hard no one recognise you.\nIncrement will 3 to 4% max to max.
# 2  Some top level management people bring bad name to the company because of their activities which affect good top level management people too.\nSome BUs do micro management and some are asking to work extra hours. My friend's BU asked him to work on Saturday and Sunday which is against company's policy but to he persons who worked like that didn't Speak Up.  Director of the project knows that too and not supportive to employees' voice.\nSome Managers are very good and directly will tell you not to work on weekends.\nSo it is upto in which BU you are and who is your manager....Read More
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Culture, micro management, unprofessional behavior, lack of sensitivity, pathetic HR and PMO
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Medical insurance amount is quite low compare to TCS . Cab pick up and drop is not from home, it's only from near by defined point.
#
#                                                                                                                                                                                                                                                                                                    Likes_cleaned  \
# 0                                                                                                                                                                                                     deserved candidates promoted promptly. unbiased providing opportunities employees, regardless gender thing
# 1                                                                                                                                                                                                                    got lot learning platform monthly learning plan well. people encourage cloud certificating.
# 2  based business unit get experience. company's policies good followed top level management people. bus respect employees personal time not. may directly tell work extra hours days though may fault developing something. canspeak troubles facing anonymously heard actions taken. that's best thing....read
# 3                                                                                                                                                                                                                                                                     client projects good use latest tech work.
# 4                                                     worked ibm (4 years) ,tcs (1 year) , 3rd company (1.3 years completed time review) , would say capgemini better ibm tcs. work life balance good capgemini, additionally growth opportunity also good hard worker. end forget also depends project manager.
#
#                                                                                                                                                                                                                                                                                                                                                         Dislikes_cleaned
# 0                                                                                                                                                                                                                                                                                                             designation promotions good salary increment also required
# 1                                                                                                                                                                                                                                                            get fully tech project. variable pay. no, appraisal. worked hard one recognise you. increment 3 4% max max.
# 2  top level management people bring bad name company activities affect good top level management people too. bus micro management asking work extra hours. friend's bu asked work saturday sunday company's policy persons worked like speak up. director project knows supportive employees' voice. managers good directly tell work weekends. upto bu manager....read
# 3                                                                                                                                                                                                                                                                                  culture, micro management, unprofessional behavior, lack sensitivity, pathetic hr pmo
# 4                                                                                                                                                                                                                                                                               medical insurance amount quite low compare tcs . cab pick drop home, near defined point.

# %%
num=0
for i in df_processed.index:
  print(df_processed.loc[i, 'Likes'])
  print(df_processed.loc[i, 'Likes_cleaned'])
  print()
  num=num+1
  if num==5:
    break
# Out:
# Deserved candidates are promoted promptly.
# Unbiased in providing opportunities to employees, regardless of their gender or any other thing
# deserved candidates promoted promptly. unbiased providing opportunities employees, regardless gender thing
#
# You got lot of learning platform and monthly learning plan as well.
# People will be encourage for cloud certificating.
# got lot learning platform monthly learning plan well. people encourage cloud certificating.
#
# Based on which Business Unit you are you will get your experience.
# Company's policies are good and is followed by most of the top level management people.
# Some BUs respect employees personal time and some are not. They may directly tell you to work extra hours and days though it may not be your fault in developing something.
# You canSpeak up what are the troubles you are facing anonymously and is heard and actions are taken. That's the best thing....Read More
# based business unit get experience. company's policies good followed top level management people. bus respect employees personal time not. may directly tell work extra hours days though may fault developing something. canspeak troubles facing anonymously heard actions taken. that's best thing....read
#
# Some client projects are good as they use the latest tech to work.
# client projects good use latest tech work.
#
# I have worked in IBM (4 years) ,TCS (1 year) , this is my 3rd company (1.3 years completed at the time of review) ,  I would say Capgemini is better than IBM and TCS. Work Life balance is very good in capgemini, additionally growth opportunity is also good here if you are hard a worker. At the end don't forget it also depends on your project and manager.
# worked ibm (4 years) ,tcs (1 year) , 3rd company (1.3 years completed time review) , would say capgemini better ibm tcs. work life balance good capgemini, additionally growth opportunity also good hard worker. end forget also depends project manager.

# %% [markdown]
# ### Remove Punctuation (. & ,)

# %%
# Fungsi untuk menghapus tanda baca
def remove_punctuation(text):
    # Menghapus tanda baca dan menggantinya dengan spasi
    cleaned_text = re.sub(r'[.,]', ' ', text)
    # Menghapus spasi ganda yang mungkin terbentuk
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    return cleaned_text


# Mengaplikasikan fungsi ke kolom teks yang diinginkan pada DataFrame yang baru
df_processed['Likes_cleaned'] = df_processed['Likes_cleaned'].apply(remove_punctuation)
df_processed['Dislikes_cleaned'] = df_processed['Dislikes_cleaned'].apply(remove_punctuation)

pd.set_option('display.max_colwidth', None)

# Menampilkan hasilnya
print(df_processed[['Likes','Dislikes','Likes_cleaned', 'Dislikes_cleaned']].head(10))
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Likes  \
# 0                                                                                                                                                                                                                                                                                                                                        Deserved candidates are promoted promptly.\nUnbiased in providing opportunities to employees, regardless of their gender or any other thing
# 1                                                                                                                                                                                                                                                                                                                                                             You got lot of learning platform and monthly learning plan as well.\nPeople will be encourage for cloud certificating.
# 2  Based on which Business Unit you are you will get your experience.\nCompany's policies are good and is followed by most of the top level management people.\nSome BUs respect employees personal time and some are not. They may directly tell you to work extra hours and days though it may not be your fault in developing something.\nYou canSpeak up what are the troubles you are facing anonymously and is heard and actions are taken. That's the best thing....Read More
# 3                                                                                                                                                                                                                                                                                                                                                                                                                 Some client projects are good as they use the latest tech to work.
# 4                                                                                                               I have worked in IBM (4 years) ,TCS (1 year) , this is my 3rd company (1.3 years completed at the time of review) ,  I would say Capgemini is better than IBM and TCS. Work Life balance is very good in capgemini, additionally growth opportunity is also good here if you are hard a worker. At the end don't forget it also depends on your project and manager.
# 5                                                                                                                                                                                                                                                                                                                             All good and their learning platforms and skill development with full free hands and core knowledge expert in very process of projects and deliveries.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                     Flexible timing, good project, learning growth
# 7                                                                                                                                                                                                                                                                                                   You can stay here without a project, without any work on bench. Nobody will fire you. \nYou can stay here, learn from their courses and prepare for some other exam or other job
# 8                                                                                                                                                                                                                                                                                                              The experience might vary based on the project you are tagged to, I'm in Consulting and my team is really supportive, so my overall experience is good no complaints.
# 9                                                                                                                                                                                                                                                                                                                                                                                                                   Learning new features from my project\nWork life balance is good
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Dislikes  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               With designation promotions good salary increment is also required
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                   You will get fully not tech project.\nThere is no variable pay.\nNo, appraisal. \nif you worked hard no one recognise you.\nIncrement will 3 to 4% max to max.
# 2  Some top level management people bring bad name to the company because of their activities which affect good top level management people too.\nSome BUs do micro management and some are asking to work extra hours. My friend's BU asked him to work on Saturday and Sunday which is against company's policy but to he persons who worked like that didn't Speak Up.  Director of the project knows that too and not supportive to employees' voice.\nSome Managers are very good and directly will tell you not to work on weekends.\nSo it is upto in which BU you are and who is your manager....Read More
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Culture, micro management, unprofessional behavior, lack of sensitivity, pathetic HR and PMO
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Medical insurance amount is quite low compare to TCS . Cab pick up and drop is not from home, it's only from near by defined point.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         Hike cycle and performance hikes are bit low and average
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  There is no anniversary culture for new employee, of you join on the month of May, you are going to get the hike after 2 years.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                I begged them for a project, but they kept me on bench for a year. I was a fresher, so I was dying for some work\nThe management is terrible, the manager cut my leaves, saying I had an attitude
# 8                                                                                                                                                                                                                                                                No company or job is perfect, the learning opportunity will get stagnated at some point (might not be the case with development project) especially support projects, also there is no opportunity to have a transition into different roles, and the compensation and promotion is average, other than  this cg is a really great place to work.
# 9                                                                                                                                                                                                                                                                                                                                                                                                           There are no long term project, every 10 months once project getting changed. Again KT and machine setting is taking time. Internal politics are there, even if you work hard you will get 2nd rating.
#
#                                                                                                                                                                                                                                                                                            Likes_cleaned  \
# 0                                                                                                                                                                                               deserved candidates promoted promptly unbiased providing opportunities employees regardless gender thing
# 1                                                                                                                                                                                                             got lot learning platform monthly learning plan well people encourage cloud certificating
# 2  based business unit get experience company's policies good followed top level management people bus respect employees personal time not may directly tell work extra hours days though may fault developing something canspeak troubles facing anonymously heard actions taken that's best thing read
# 3                                                                                                                                                                                                                                                             client projects good use latest tech work
# 4                                                     worked ibm (4 years) tcs (1 year) 3rd company (1 3 years completed time review) would say capgemini better ibm tcs work life balance good capgemini additionally growth opportunity also good hard worker end forget also depends project manager
# 5                                                                                                                                                                                           good learning platforms skill development full free hands core knowledge expert process projects deliveries
# 6                                                                                                                                                                                                                                                           flexible timing good project learning growth
# 7                                                                                                                                                                                                       stay without project without work bench nobody fire you stay here learn courses prepare exam job
# 8                                                                                                                                                                                experience might vary based project tagged to i'm consulting team really supportive overall experience good complaints
# 9                                                                                                                                                                                                                                                   learning new features project work life balance good
#
#                                                                                                                                                                                                                                                                                                                                                 Dislikes_cleaned
# 0                                                                                                                                                                                                                                                                                                     designation promotions good salary increment also required
# 1                                                                                                                                                                                                                                                         get fully tech project variable pay no appraisal worked hard one recognise you increment 3 4% max max
# 2  top level management people bring bad name company activities affect good top level management people too bus micro management asking work extra hours friend's bu asked work saturday sunday company's policy persons worked like speak up director project knows supportive employees' voice managers good directly tell work weekends upto bu manager read
# 3                                                                                                                                                                                                                                                                              culture micro management unprofessional behavior lack sensitivity pathetic hr pmo
# 4                                                                                                                                                                                                                                                                          medical insurance amount quite low compare tcs cab pick drop home near defined point
# 5                                                                                                                                                                                                                                                                                                                   hike cycle performance hikes bit low average
# 6                                                                                                                                                                                                                                                                                        anniversary culture new employee join month may going get hike 2 years
# 7                                                                                                                                                                                                                                                       begged project kept bench year fresher dying work management terrible manager cut leaves saying attitude
# 8                                                                                                                               company job perfect learning opportunity get stagnated point (might case development project) especially support projects also opportunity transition different roles compensation promotion average cg really great place work
# 9                                                                                                                                                                                                                long term project every 10 months project getting changed kt machine setting taking time internal politics there even work hard get 2nd rating

# %%
num=0
for i in df_processed.index:
  print(df_processed.loc[i, 'Likes'])
  print(df_processed.loc[i, 'Likes_cleaned'])
  print()
  num=num+1
  if num==5:
    break
# Out:
# Deserved candidates are promoted promptly.
# Unbiased in providing opportunities to employees, regardless of their gender or any other thing
# deserved candidates promoted promptly unbiased providing opportunities employees regardless gender thing
#
# You got lot of learning platform and monthly learning plan as well.
# People will be encourage for cloud certificating.
# got lot learning platform monthly learning plan well people encourage cloud certificating
#
# Based on which Business Unit you are you will get your experience.
# Company's policies are good and is followed by most of the top level management people.
# Some BUs respect employees personal time and some are not. They may directly tell you to work extra hours and days though it may not be your fault in developing something.
# You canSpeak up what are the troubles you are facing anonymously and is heard and actions are taken. That's the best thing....Read More
# based business unit get experience company's policies good followed top level management people bus respect employees personal time not may directly tell work extra hours days though may fault developing something canspeak troubles facing anonymously heard actions taken that's best thing read
#
# Some client projects are good as they use the latest tech to work.
# client projects good use latest tech work
#
# I have worked in IBM (4 years) ,TCS (1 year) , this is my 3rd company (1.3 years completed at the time of review) ,  I would say Capgemini is better than IBM and TCS. Work Life balance is very good in capgemini, additionally growth opportunity is also good here if you are hard a worker. At the end don't forget it also depends on your project and manager.
# worked ibm (4 years) tcs (1 year) 3rd company (1 3 years completed time review) would say capgemini better ibm tcs work life balance good capgemini additionally growth opportunity also good hard worker end forget also depends project manager

# %% [markdown]
# ### Remove other punctuation, number

# %%
# Fungsi untuk menghapus karakter selain huruf dan spasi
def remove_non_alpha(text):
    # Menghapus karakter selain huruf dan spasi

    cleaned_text = re.sub(r'\b1st\b', 'first', text)
    cleaned_text = re.sub(r'\b2nd\b', 'second', cleaned_text)
    cleaned_text = re.sub(r'\b3rd\b', 'third', cleaned_text)
    cleaned_text = re.sub(r'\b1\b', 'one', cleaned_text)
    cleaned_text = re.sub(r'\b2\b', 'two', cleaned_text)
    cleaned_text = re.sub(r'\b3\b', 'three', cleaned_text)
    cleaned_text = re.sub(r'\b4\b', 'four', cleaned_text)
    cleaned_text = re.sub(r'\b5\b', 'five', cleaned_text)
    cleaned_text = re.sub(r'\b6\b', 'six', cleaned_text)
    cleaned_text = re.sub(r'\b7\b', 'seven', cleaned_text)
    cleaned_text = re.sub(r'\b8\b', 'eight', cleaned_text)
    cleaned_text = re.sub(r'\b9\b', 'nine', cleaned_text)
    cleaned_text = re.sub(r'\b10\b', 'ten', cleaned_text)
    cleaned_text = re.sub(r'\s+', ' ', cleaned_text)
    cleaned_text = re.sub(r'[^a-zA-Z\s]', '', cleaned_text)
    return cleaned_text

# Mengaplikasikan fungsi ke kolom teks yang diinginkan pada DataFrame yang baru
df_processed['Likes_cleaned'] = df_processed['Likes_cleaned'].apply(remove_non_alpha)
df_processed['Dislikes_cleaned'] = df_processed['Dislikes_cleaned'].apply(remove_non_alpha)

# Menampilkan hasilnya
num=0
for i in df_processed.index:
  print(df_processed.loc[i, 'Likes'])
  print(df_processed.loc[i, 'Likes_cleaned'])
  print()
  num=num+1
  if num==5:
    break
# Out:
# Deserved candidates are promoted promptly.
# Unbiased in providing opportunities to employees, regardless of their gender or any other thing
# deserved candidates promoted promptly unbiased providing opportunities employees regardless gender thing
#
# You got lot of learning platform and monthly learning plan as well.
# People will be encourage for cloud certificating.
# got lot learning platform monthly learning plan well people encourage cloud certificating
#
# Based on which Business Unit you are you will get your experience.
# Company's policies are good and is followed by most of the top level management people.
# Some BUs respect employees personal time and some are not. They may directly tell you to work extra hours and days though it may not be your fault in developing something.
# You canSpeak up what are the troubles you are facing anonymously and is heard and actions are taken. That's the best thing....Read More
# based business unit get experience companys policies good followed top level management people bus respect employees personal time not may directly tell work extra hours days though may fault developing something canspeak troubles facing anonymously heard actions taken thats best thing read
#
# Some client projects are good as they use the latest tech to work.
# client projects good use latest tech work
#
# I have worked in IBM (4 years) ,TCS (1 year) , this is my 3rd company (1.3 years completed at the time of review) ,  I would say Capgemini is better than IBM and TCS. Work Life balance is very good in capgemini, additionally growth opportunity is also good here if you are hard a worker. At the end don't forget it also depends on your project and manager.
# worked ibm four years tcs one year third company one three years completed time review would say capgemini better ibm tcs work life balance good capgemini additionally growth opportunity also good hard worker end forget also depends project manager

# %%
num=0
for i in df_processed.index:
  print(df_processed.loc[i, 'Likes'])
  print(df_processed.loc[i, 'Likes_cleaned'])
  print()
  num=num+1
  if num==5:
    break
# Out:
# Deserved candidates are promoted promptly.
# Unbiased in providing opportunities to employees, regardless of their gender or any other thing
# deserved candidates promoted promptly unbiased providing opportunities employees regardless gender thing
#
# You got lot of learning platform and monthly learning plan as well.
# People will be encourage for cloud certificating.
# got lot learning platform monthly learning plan well people encourage cloud certificating
#
# Based on which Business Unit you are you will get your experience.
# Company's policies are good and is followed by most of the top level management people.
# Some BUs respect employees personal time and some are not. They may directly tell you to work extra hours and days though it may not be your fault in developing something.
# You canSpeak up what are the troubles you are facing anonymously and is heard and actions are taken. That's the best thing....Read More
# based business unit get experience companys policies good followed top level management people bus respect employees personal time not may directly tell work extra hours days though may fault developing something canspeak troubles facing anonymously heard actions taken thats best thing read
#
# Some client projects are good as they use the latest tech to work.
# client projects good use latest tech work
#
# I have worked in IBM (4 years) ,TCS (1 year) , this is my 3rd company (1.3 years completed at the time of review) ,  I would say Capgemini is better than IBM and TCS. Work Life balance is very good in capgemini, additionally growth opportunity is also good here if you are hard a worker. At the end don't forget it also depends on your project and manager.
# worked ibm years tcs year rd company years completed time review would say capgemini better ibm tcs work life balance good capgemini additionally growth opportunity also good hard worker end forget also depends project manager

# %% [markdown]
# ### Slang Words

# %%
#Daftar kata-kata yang ingin diganti dan penggantinya
replacements = {
    r'\bcg\b': 'capgemini',
    r'\bnanipulstive\b':'manipulative',
    r'\bharashful\b':'harshful',
    r'\bcanspeak\b':'can speak',
    r'\bsallery\b':'salary',
    r'\bemloyees\b':'employees',
    r'\bharashment\b':'harassment',
    r'\bsallery\b':'salary',

    # Tambahkan lebih banyak pasangan kata yang ingin diganti di sini
}

# Fungsi untuk mengganti kata-kata sesuai dengan daftar replacements
def replace_words(text, replacements):
    for old_word, new_word in replacements.items():
        text = re.sub(old_word, new_word, text)
    return text

#Mengaplikasikan fungsi ke kolom 'Likes' dan 'Dislikes' dalam df_processed
df_processed['Likes_cleaned'] = df_processed['Likes_cleaned'].apply(lambda x: replace_words(x, replacements))
df_processed['Dislikes_cleaned'] = df_processed['Dislikes_cleaned'].apply(lambda x: replace_words(x, replacements))

#Menampilkan hasilnya
num=0
for i in df_processed.index:
  print(df_processed.loc[i, 'Likes'])
  print(df_processed.loc[i, 'Likes_cleaned'])
  print()
  num=num+1
  if num==5:
    break
# Out:
# Deserved candidates are promoted promptly.
# Unbiased in providing opportunities to employees, regardless of their gender or any other thing
# deserved candidates promoted promptly unbiased providing opportunities employees regardless gender thing
#
# You got lot of learning platform and monthly learning plan as well.
# People will be encourage for cloud certificating.
# got lot learning platform monthly learning plan well people encourage cloud certificating
#
# Based on which Business Unit you are you will get your experience.
# Company's policies are good and is followed by most of the top level management people.
# Some BUs respect employees personal time and some are not. They may directly tell you to work extra hours and days though it may not be your fault in developing something.
# You canSpeak up what are the troubles you are facing anonymously and is heard and actions are taken. That's the best thing....Read More
# based business unit get experience companys policies good followed top level management people bus respect employees personal time not may directly tell work extra hours days though may fault developing something can speak troubles facing anonymously heard actions taken thats best thing read
#
# Some client projects are good as they use the latest tech to work.
# client projects good use latest tech work
#
# I have worked in IBM (4 years) ,TCS (1 year) , this is my 3rd company (1.3 years completed at the time of review) ,  I would say Capgemini is better than IBM and TCS. Work Life balance is very good in capgemini, additionally growth opportunity is also good here if you are hard a worker. At the end don't forget it also depends on your project and manager.
# worked ibm four years tcs one year third company one three years completed time review would say capgemini better ibm tcs work life balance good capgemini additionally growth opportunity also good hard worker end forget also depends project manager

# %% [markdown]
# ### Lemmatization

# %%
def custom_lemmatization(text, exclude_words=[]):
    lemmatizer = WordNetLemmatizer()
    words = text.split()
    lemmatized_words = [lemmatizer.lemmatize(word) if word.lower() not in exclude_words else word for word in words]
    lemmatized_text = ' '.join(lemmatized_words)
    return lemmatized_text

# Mengaplikasikan fungsi ke kolom teks yang diinginkan pada DataFrame yang baru
df_processed['Likes_cleaned'] = df_processed['Likes_cleaned'].apply(custom_lemmatization)
df_processed['Dislikes_cleaned'] = df_processed['Dislikes_cleaned'].apply(custom_lemmatization)

# Menampilkan hasilnya
num=0
for i in df_processed.index:
  print(df_processed.loc[i, 'Likes'])
  print(df_processed.loc[i, 'Likes_cleaned'])
  print()
  num=num+1
  if num==5:
    break
# Out:
# Deserved candidates are promoted promptly.
# Unbiased in providing opportunities to employees, regardless of their gender or any other thing
# deserved candidate promoted promptly unbiased providing opportunity employee regardless gender thing
#
# You got lot of learning platform and monthly learning plan as well.
# People will be encourage for cloud certificating.
# got lot learning platform monthly learning plan well people encourage cloud certificating
#
# Based on which Business Unit you are you will get your experience.
# Company's policies are good and is followed by most of the top level management people.
# Some BUs respect employees personal time and some are not. They may directly tell you to work extra hours and days though it may not be your fault in developing something.
# You canSpeak up what are the troubles you are facing anonymously and is heard and actions are taken. That's the best thing....Read More
# based business unit get experience company policy good followed top level management people bus respect employee personal time not may directly tell work extra hour day though may fault developing something can speak trouble facing anonymously heard action taken thats best thing read
#
# Some client projects are good as they use the latest tech to work.
# client project good use latest tech work
#
# I have worked in IBM (4 years) ,TCS (1 year) , this is my 3rd company (1.3 years completed at the time of review) ,  I would say Capgemini is better than IBM and TCS. Work Life balance is very good in capgemini, additionally growth opportunity is also good here if you are hard a worker. At the end don't forget it also depends on your project and manager.
# worked ibm four year tc one year third company one three year completed time review would say capgemini better ibm tc work life balance good capgemini additionally growth opportunity also good hard worker end forget also depends project manager

# %%
# Simpan DataFrame ke dalam file CSV
df_processed.to_csv('/content/drive/MyDrive/preprocessing12.csv', index=False)
