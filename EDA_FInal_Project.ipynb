# %% [markdown]
# <a href="https://colab.research.google.com/github/Efradgalio/Employee-Sentiment-Tracker/blob/main/EDA_FInal_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import essential library
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns
import altair as alt
from collections import Counter

#%matplotlib inline
#sns.set(color_codes=True)

from google.colab import drive

# %%
# Load Data
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Colab Notebooks/Capgemini_Employee_Reviews_from_AmbitionBox.csv'

# Load the data
data = pd.read_csv(file_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# rows & columns
num_row, num_col = data.shape
print('The dataset consist of  {} rows and {} columns.'.format(num_row, num_col))
# Out:
# The dataset consist of  27013 rows and 14 columns.

# %%
# Check Atribute
print('Attributes : ', data.columns.values)
# Out:
# Attributes :  ['Title' 'Place' 'Job_type' 'Department' 'Date' 'Overall_rating'
#  'work_life_balance' 'skill_development' 'salary_and_benefits'
#  'job_security' 'career_growth' 'work_satisfaction' 'Likes' 'Dislikes']

# %%
# data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27013 entries, 0 to 27012
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                25932 non-null  object
#  1   Place                24613 non-null  object
#  2   Job_type             11576 non-null  object
#  3   Department           22103 non-null  object
#  4   Date                 25935 non-null  object
#  5   Overall_rating       25918 non-null  float64
#  6   work_life_balance    26997 non-null  float64
#  7   skill_development    26996 non-null  float64
#  8   salary_and_benefits  26967 non-null  float64
#  9   job_security         26963 non-null  float64
#  10  career_growth        26951 non-null  float64
#  11  work_satisfaction    26929 non-null  float64
#  12  Likes                23884 non-null  object
#  13  Dislikes             22986 non-null  object
# dtypes: float64(7), object(7)
# memory usage: 2.9+ MB

# %%
# Define a function to create a frequency dataframe and a bar chart
def create_chart(data, column):
    frequency = data[column].value_counts()
    frequency_df = frequency.reset_index()

    # Rename
    frequency_df.columns = [column, 'Frequency']
    # Sort
    frequency_df = frequency_df.sort_values(column)
    # Chart
    chart = alt.Chart(frequency_df).mark_bar().encode(
        x=alt.X(f'{column}:N', title=column, sort='x'),  # Sort the bars by the column
        y=alt.Y('Frequency:Q', title='Frequency'),
        color=alt.Color(f'{column}:N', legend=alt.Legend(title=column))  # Use the column for the color encoding
    ).properties(width=600, title=f'{column} Bar Chart')


    text = chart.mark_text(
        align='left',
        baseline='middle',
        dx=3  # Nudges text to right so it doesn't appear on top of the bar
    ).encode(
        text='Frequency:Q'
    )
    return (chart + text)

# Create a bar chart
columns = ['Overall_rating', 'work_life_balance', 'skill_development', 'salary_and_benefits', 'job_security', 'career_growth', 'work_satisfaction']
charts = [create_chart(data, column) for column in columns]
combined_chart = alt.vconcat(*charts).resolve_scale(color='independent')

# Display the chart
combined_chart
# Out:
# alt.VConcatChart(...)

# %%
# Check duplicate data
duplicate_counts = {}
for column in data.columns:
    duplicate_counts[column] = data.duplicated(subset=[column]).sum()

for column, count in duplicate_counts.items():
    print(f"Number of duplicate entries in {column}: {count}")
# Out:
# Number of duplicate entries in Title: 22768
# Number of duplicate entries in Place: 26182
# Number of duplicate entries in Job_type: 27007
# Number of duplicate entries in Department: 26391
# Number of duplicate entries in Date: 26273
# Number of duplicate entries in Overall_rating: 27007
# Number of duplicate entries in work_life_balance: 27007
# Number of duplicate entries in skill_development: 27007
# Number of duplicate entries in salary_and_benefits: 27007
# Number of duplicate entries in job_security: 27007
# Number of duplicate entries in career_growth: 27007
# Number of duplicate entries in work_satisfaction: 27007
# Number of duplicate entries in Likes: 9514
# Number of duplicate entries in Dislikes: 9464

# %%
print(data.isnull().sum())
# Out:
# Title                   1081
# Place                   2400
# Job_type               15437
# Department              4910
# Date                    1078
# Overall_rating          1095
# work_life_balance         16
# skill_development         17
# salary_and_benefits       46
# job_security              50
# career_growth             62
# work_satisfaction         84
# Likes                   3129
# Dislikes                4027
# dtype: int64

# %%
data.head(100)
# Out:
#                        Title                           Place   Job_type  \
# 0          Senior Consultant                            Pune  Full Time
# 1   Senior Software Engineer            Kolkata, West Bengal  Full Time
# 2          Senior Consultant  Bengaluru/Bangalore, Karnataka  Full Time
# 3          Senior Consultant               Pune, Maharashtra  Full Time
# 4                  Team Lead            Noida, Uttar Pradesh  Full Time
# ..                       ...                             ...        ...
# 95                 Team Lead                         Chennai  Full Time
# 96         Senior Consultant            Noida, Uttar Pradesh  Full Time
# 97            Senior Analyst                            Pune  Full Time
# 98         Gcp Data Engineer                            Pune  Full Time
# 99         Senior Consultant        Navi Mumbai, Maharashtra  Full Time
#
#                                     Department      Date  Overall_rating  \
# 0                 General Insurance Department  8-Sep-23             4.0
# 1              Software Development Department  7-Sep-23             3.0
# 2              Software Development Department  6-Sep-23             4.0
# 3                Banking Operations Department  6-Sep-23             1.0
# 4        IT Infrastructure Services Department  5-Sep-23             4.0
# ..                                         ...       ...             ...
# 95                       Operations Department  3-Aug-23             4.0
# 96       IT Infrastructure Services Department  2-Aug-23             4.0
# 97             Software Development Department  2-Aug-23             4.0
# 98  Data Science & Machine Learning Department  2-Aug-23             1.0
# 99       IT Infrastructure Services Department  2-Aug-23             1.0
#
#     work_life_balance  skill_development  salary_and_benefits  job_security  \
# 0                 4.0                3.0                  3.0           4.0
# 1                 4.0                4.0                  3.0           4.0
# 2                 4.0                5.0                  3.0           3.0
# 3                 2.0                4.0                  1.0           4.0
# 4                 5.0                4.0                  4.0           4.0
# ..                ...                ...                  ...           ...
# 95                4.0                5.0                  3.0           5.0
# 96                4.0                3.0                  4.0           3.0
# 97                2.0                4.0                  2.0           4.0
# 98                1.0                1.0                  1.0           1.0
# 99                2.0                1.0                  1.0           1.0
#
#     career_growth  work_satisfaction  \
# 0             4.0                4.0
# 1             4.0                3.0
# 2             4.0                3.0
# 3             1.0                1.0
# 4             4.0                3.0
# ..            ...                ...
# 95            4.0                3.0
# 96            4.0                3.0
# 97            3.0                2.0
# 98            1.0                1.0
# 99            1.0                1.0
#
#                                                 Likes  \
# 0   Deserved candidates are promoted promptly.\nUn...
# 1   You got lot of learning platform and monthly l...
# 2   Based on which Business Unit you are you will ...
# 3   Some client projects are good as they use the ...
# 4   I have worked in IBM (4 years) ,TCS (1 year) ,...
# ..                                                ...
# 95  CG as a company is very good for women profess...
# 96  1. Usually 1 person remains allocated to one p...
# 97  I got to work on a better ERP.\nLaptop & asset...
# 98                                            Nothing
# 99  Well the only thing about Capgemini is that it...
#
#                                              Dislikes
# 0   With designation promotions good salary increm...
# 1   You will get fully not tech project.\nThere is...
# 2   Some top level management people bring bad nam...
# 3   Culture, micro management, unprofessional beha...
# 4   Medical insurance amount is quite low compare ...
# ..                                                ...
# 95  No growth in terms of salary hike when you sta...
# 96  On your exit, remaining amount of health insur...
# 97  Note: This is only based on the project that I...
# 98  Capsgimini don't have any project. They hire p...
# 99  Politics even at the HR level\nAppraisal amoun...
#
# [100 rows x 14 columns]

# %%
dislikes = data['Dislikes']

# Convert all entries to strings (assuming numbers are convertible)
dislikes_str = [str(entry) for entry in dislikes]

word_freq = Counter(" ".join(dislikes_str).split())

# Get the top N most frequent words (adjust N as needed)
top_words = word_freq.most_common(100)  # Change 5 to desired number of entries

# Print table header
print("{:<15} {:<10}".format("Word", "Count"))
print("-" * 25)

# Print each word and its count in a row
for word, count in top_words:
  print("{:<15} {:<10}".format(word, count))
# Out:
# Word            Count
# -------------------------
# and             6116
# is              5898
# to              5196
# nan             4027
# the             3652
# work            3081
# not             2596
# are             2580
# in              2558
# of              2550
# No              2549
# for             2423
# good            2375
# Nothing         2075
# you             1864
# no              1837
# a               1783
# I               1708
# very            1433
# Work            1414
# Salary          1300
# life            1290
# on              1288
# as              1259
# company         1230
# they            1122
# with            1069
# balance         1061
# have            1052
# growth          995
# salary          978
# hike            972
# be              961
# Good            934
# will            933
# culture         814
# project         792
# management      768
# but             751
# from            739
# less            724
# like            707
# get             699
# at              699
# working         689
# Capgemini       686
# that            682
# your            669
# was             659
# my              637
# any             628
# employees       624
# job             605
# The             597
# Not             589
# there           586
# all             586
# if              583
# much            579
# Compensation    561
# They            559
# about           556
# security        540
# or              538
# There           537
# this            532
# it              527
# career          525
# appraisal       518
# team            507
# Everything      500
# people          496
# can             491
# even            490
# more            479
# hikes           472
# Job             471
# don't           466
# projects        460
# dislike         458
# Management      457
# nothing         454
# Appraisal       452
# environment     446
# employee        444
# which           438
# only            418
# HR              404
# bad             400
# time            396
# compensation    395
# so              393
# politics        391
# one             389
# ,               386
# experience      384
# low             382
# other           381
# their           375
# benefits        370

# %%
from collections import Counter

likes = data['Likes']

# Convert all entries to strings (assuming numbers are convertible)
likes_str = [str(entry) for entry in likes]

word_freq_likes = Counter(" ".join(likes_str).split())

# Get the top N most frequent words (adjust N as needed)
top_words_likes = word_freq_likes.most_common(100)  # Change 5 to desired number of entries


print("{:<15} {:<10}".format("Word", "Count"))
print("-" * 25)

for word, count in top_words_likes:
  print("{:<15} {:<10}".format(word, count))
# Out:
# Word            Count
# -------------------------
# and             6732
# is              5515
# to              5448
# work            4947
# good            4317
# Work            3342
# nan             3130
# the             3119
# Good            2849
# life            2606
# in              2345
# of              2280
# balance         2262
# are             2260
# for             2164
# I               2133
# company         2034
# culture         2019
# a               1927
# you             1532
# Nothing         1520
# very            1400
# with            1267
# environment     1260
# not             1162
# Capgemini       1109
# security        1052
# on              1049
# Job             1000
# working         982
# No              978
# as              913
# have            913
# like            859
# learning        845
# was             821
# will            817
# place           800
# team            760
# no              751
# from            727
# job             719
# they            712
# my              709
# good.           696
# The             687
# management      671
# growth          652
# your            650
# project         647
# be              639
# but             633
# it              623
# get             604
# all             588
# at              587
# experience      583
# learn           574
# this            568
# opportunities   560
# Company         554
# that            548
# can             539
# salary          512
# about           494
# new             479
# if              477
# career          473
# Learning        448
# employees       444
# great           442
# people          430
# It              430
# ,               427
# there           418
# Salary          415
# Very            393
# which           390
# Everything      389
# much            386
# hike            383
# any             382
# policies        382
# It's            372
# projects        370
# Great           369
# .               368
# more            363
# nothing         346
# They            345
# also            345
# best            339
# so              337
# There           335
# one             331
# opportunity     326
# really          325
# Culture         324
# i               320
# time            319
